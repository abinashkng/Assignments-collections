# %% [markdown]
# <a href="https://colab.research.google.com/github/abinashkng/Assignments-collections/blob/main/UniAcco_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #importing packages

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Loading

# %%
data = pd.read_excel('/UniAcco_Data_Science_Internship.xlsx')

# %%
data.head()
# Out:
#                                                  Agent_id status  \
# 0  0.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1  1.0  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2  2.0  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3  3.0  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4  4.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
#
#       lost_reason                budget                                lease  \
# 0  Not responding                   NaN                                  NaN
# 1      Low budget                   NaN                                  NaN
# 2  Not responding  £121 - £180 Per Week  Full Year Course Stay 40 - 44 weeks
# 3      Low budget                   0-0                                  0.0
# 4       Junk lead                   NaN                                  NaN
#
#     movein                                             source  \
# ...

# %%
data.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-fc67ba1e18ed> in <module>
# ----> 1 data.na
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'na'

# %%
data.describe()
# Out:
#                           movein
# count  46608.00000  32970.000000
# mean   23303.50000  44822.710282
# std    13454.71501    320.993893
# min        0.00000  25569.000000
# 25%    11651.75000  44805.000000
# 50%    23303.50000  44814.000000
# 75%    34955.25000  44823.000000
# max    46607.00000  45539.000000
